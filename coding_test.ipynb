# %% [markdown]
# # Coding-Test
# * Candidate: José Maria Clementino Junior

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# Necessary imports

# %%
import pandas as pd
import os 
import glob
! pip install pandasql
from pandasql import sqldf
import json
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: pandasql in c:\users\junin\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: sqlalchemy in c:\users\junin\anaconda3\lib\site-packages (from pandasql) (1.4.22)
# Requirement already satisfied: numpy in c:\users\junin\anaconda3\lib\site-packages (from pandasql) (1.20.3)
# Requirement already satisfied: pandas in c:\users\junin\anaconda3\lib\site-packages (from pandasql) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\junin\anaconda3\lib\site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\junin\anaconda3\lib\site-packages (from pandas->pandasql) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\junin\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\junin\anaconda3\lib\site-packages (from sqlalchemy->pandasql) (1.1.1)

# %%
current_directory = os.getcwd()
mydir = current_directory
file_list = glob.glob(mydir + "/*.csv")

# %%
file_list
# Out:
# ['C:\\Users\\junin\\Downloads\\codingSkills-main\\codingSkills-main\\admissions.csv',
#  'C:\\Users\\junin\\Downloads\\codingSkills-main\\codingSkills-main\\d_labitems.csv',
#  'C:\\Users\\junin\\Downloads\\codingSkills-main\\codingSkills-main\\edstays.csv',
#  'C:\\Users\\junin\\Downloads\\codingSkills-main\\codingSkills-main\\labevents.csv']

# %%
list_df = []
for i in file_list:
    df = pd.read_csv(i)
    list_df.append(df)

# %%
df_admissions = list_df[0]
df_labitems = list_df[1]
df_edstays = list_df[2]
df_labevents = list_df[3]

# %% [markdown]
# ## Reading the data

# %%
df_admissions.head(5)
# Out:
#    subject_id   hadm_id            admittime            dischtime  \
# 0    10004235  24181354  2196-02-24T14:38:00  2196-03-04T14:02:00
# 1    10009628  25926192  2153-09-17T17:08:00  2153-09-25T13:20:00
# 2    10018081  23983182  2134-08-18T02:02:00  2134-08-23T19:35:00
# 3    10006053  22942076  2111-11-13T23:39:00  2111-11-15T17:20:00
# 4    10031404  21606243  2113-08-04T18:46:00  2113-08-06T20:57:00
#
#              deathtime admission_type      admission_location  \
# 0                  NaN         URGENT  TRANSFER FROM HOSPITAL
# 1                  NaN         URGENT  TRANSFER FROM HOSPITAL
# 2                  NaN         URGENT  TRANSFER FROM HOSPITAL
# 3  2111-11-15T17:20:00         URGENT  TRANSFER FROM HOSPITAL
# 4                  NaN         URGENT  TRANSFER FROM HOSPITAL
#
#          discharge_location insurance language marital_status  \
# 0  SKILLED NURSING FACILITY  Medicaid  ENGLISH         SINGLE
# 1          HOME HEALTH CARE  Medicaid        ?        MARRIED
# 2  SKILLED NURSING FACILITY  Medicare  ENGLISH        MARRIED
# 3                      DIED  Medicaid  ENGLISH            NaN
# 4                      HOME     Other  ENGLISH        WIDOWED
#
#                 ethnicity            edregtime            edouttime  \
# 0  BLACK/AFRICAN AMERICAN  2196-02-24T12:15:00  2196-02-24T17:07:00
# 1         HISPANIC/LATINO                  NaN                  NaN
# 2                   WHITE  2134-08-17T16:24:00  2134-08-18T03:15:00
# 3                 UNKNOWN                  NaN                  NaN
# 4                   WHITE                  NaN                  NaN
#
#    hospital_expire_flag
# 0                     0
# 1                     0
# 2                     0
# 3                     1
# 4                     0

# %%
df_edstays.head(5)
# Out:
#    subject_id     hadm_id   stay_id               intime              outtime
# 0    10014729  23300884.0  32435236  2125-03-19T12:36:00  2125-03-19T16:59:47
# 1    10004235  24181354.0  36583389  2196-02-24T12:15:00  2196-02-24T17:07:00
# 2    10026255  22059910.0  30926886  2201-07-07T12:31:00  2201-07-07T19:40:00
# 3    10026255  20437651.0  36948716  2200-09-17T18:38:00  2200-09-18T00:57:00
# 4    10007058  22954658.0  35770266  2167-11-07T17:57:00  2167-11-07T20:22:00

# %%
df_labevents.head(5)
# Out:
#    labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 0       183881    10014354  29600294.0      1808066   51277
# 1       183883    10014354  29600294.0      1808066   51301
# 2       183888    10014354  29600294.0      1808066   52167
# 3       183870    10014354  29600294.0      1808066   51249
# 4       183865    10014354  29600294.0      1808066   51222
#
#              charttime            storetime value  valuenum valueuom  \
# 0  2148-08-16 00:00:00  2148-08-16 01:30:00  15.4      15.4        %
# 1  2148-08-16 00:00:00  2148-08-16 01:30:00  20.3      20.3     K/uL
# 2  2148-08-16 00:00:00  2148-08-16 01:30:00  49.7      49.7       fL
# 3  2148-08-16 00:00:00  2148-08-16 01:30:00  31.1      31.1     g/dL
# 4  2148-08-16 00:00:00  2148-08-16 01:30:00   9.2       9.2     g/dL
#
#    ref_range_lower  ref_range_upper      flag priority comments
# 0             10.5             15.5       NaN  ROUTINE      NaN
# 1              4.0             10.0  abnormal  ROUTINE      NaN
# 2             35.1             46.3  abnormal  ROUTINE      NaN
# 3             32.0             37.0  abnormal  ROUTINE      NaN
# 4             13.7             17.5  abnormal  ROUTINE      NaN

# %%
df_labitems.head(5)
# Out:
#    itemid                       label  fluid   category loinc_code
# 0   52016                         Abz  Blood  Blood Gas        NaN
# 1   52017              Albumin, Blood  Blood  Blood Gas        NaN
# 2   50801  Alveolar-arterial Gradient  Blood  Blood Gas        NaN
# 3   52018              Assist/Control  Blood  Blood Gas        NaN
# 4   50802                 Base Excess  Blood  Blood Gas        NaN

# %% [markdown]
#  #  <span style="color:blue">  1.	What is the percentage of patients admitted to the hospital that have never been to the ED? </span>

# %%
# We have 100 patients in admissions table 
total_patients = len(df_admissions['subject_id'].unique())
print(total_patients)
# Out:
# 100

# %%
#First i got all ED admissions
df_emergency_room = df_admissions.query('admission_location=="EMERGENCY ROOM"')

# %%
#After that I removed all admissions that contain the type ED from the admissions table
df_remove = df_admissions[~df_admissions.subject_id.isin(df_emergency_room.subject_id)]

# %%
#In the sequence of the table that contains the different admissions of the ED type, the filter of single patients was performed
total_dif = len(df_remove['subject_id'].unique())

# %%
#Calculation: of patients admitted to the hospital that have never been to the ED
porcent = (total_dif/total_patients)*100
print(f'Percentage of patients admitted to the hospital that have never been to the ED is {porcent} %')
# Out:
# Percentage of patients admitted to the hospital that have never been to the ED is 39.0 %

# %% [markdown]
#  #  <span style="color:blue">   2.		For each patient, generate a json with the hospital admission data. </span>

# %% [markdown]
# * My primary interpretation was to store all patients in a single JSON file, in which they can be identified by their respective ids/subject_id.
#
#
# * However, there is also the possibility of creating a JSON file for each patient. This can be easily performed with simple coding changes.

# %% [markdown]
# ##### I created two JSON files. In simple_admission.json only the data contained in the admissions table is present.

# %%
list_att = df_admissions.columns[1:]
d = (df_admissions.groupby(['subject_id'])[list_att]
       .apply(lambda x: x.to_dict('r')).to_json())
simple_json_object = json.loads(d)

# %%
for key in simple_json_object.keys():
    json_patient = simple_json_object[key]
    with open(f'{mydir}\\simple_admission_patients\\{key}.json', 'w') as fp:
        json.dump(json_patient, fp)

# %%
with open('simple_admission.json', 'w') as fp:
    json.dump(simple_json_object, fp)

# %% [markdown]
# ##### The full admission.json contains all the exam results, stay that inherit the admissions of the patients through the relationships of the tables: df_edstays, df_labevents, and df_labitems.

# %%
query = """SELECT   df_admissions.subject_id,	df_admissions.hadm_id,	df_admissions.admittime,	df_admissions.dischtime,	df_admissions.deathtime,	df_admissions.admission_type,	df_admissions.admission_location,	df_admissions.discharge_location,	df_admissions.insurance,	df_admissions.language,	df_admissions.marital_status,	df_admissions.ethnicity,	df_admissions.edregtime,	df_admissions.edouttime,	df_admissions.hospital_expire_flag,

df_edstays.stay_id, df_edstays.intime stay_intime, df_edstays.outtime stay_outime,

df_labevents.labevent_id, df_labevents.specimen_id labE_specimen_id, df_labevents.itemid labE_itemid,	df_labevents.charttime labE_charttime,	df_labevents.storetime labE_storetime,	df_labevents.value labE_value,	df_labevents.valuenum labE_valuenum,	df_labevents.valueuom labE_valueuom,	df_labevents.ref_range_lower labE_ref_range_lower,	df_labevents.ref_range_upper labE_ref_range_upper,	df_labevents.flag labE_flag,	df_labevents.priority labE_priority,	df_labevents.comments labE_comments,


df_labitems.label labI_label,	df_labitems.fluid labI_fluid,	df_labitems.category labI_category,	df_labitems.loinc_code labI_loinc_code


from  df_admissions 


LEFT JOIN df_edstays on df_edstays.hadm_id = df_admissions.hadm_id

LEFT JOIN df_labevents on df_labevents.hadm_id = df_admissions.hadm_id

INNER JOIN df_labitems on df_labitems.itemid = df_labevents.itemid;

"""

df_query_resul =sqldf(query, globals())

# %%
list_att = df_query_resul.columns[1:]
d = (df_query_resul.groupby(['subject_id'])[list_att]
       .apply(lambda x: x.to_dict('r')).to_json())
full_json_object = json.loads(d)

# %%
for key in full_json_object.keys():
    json_patient = full_json_object[key]
    with open(f'{mydir}\\full_admission_patients\\{key}.json', 'w') as fp:
        json.dump(json_patient, fp)

# %%
with open('full_admission.json', 'w') as fp:
    json.dump(full_json_object, fp)

# %% [markdown]
#   #  <span style="color:blue">  3.	Check the performance of albumin in predicting in-hospital mortality. </span>
# * a.	Use only each patient’s first admission to the hospital; and
# * b.	Only the Albumin results from the first 24h from hospital admission.

# %% [markdown]
#  ##### Before performing the queries, it is necessary to perform a summary of the initial data.
# * Total unique patients who had admissions: 100
# * Total mortality considering only the first admission and regardless of albumin:  5

# %% [markdown]
# ##### In interpreting the resolution of question 3, I considered a cumulative and dependency solution between alternatives A and B.

# %% [markdown]
# ####  a. Use only each patient’s first admission to the hospital

# %% [markdown]
# #### Using each dataframe as a table in SQL language over a Sqlite

# %%
first_query ="""

SELECT Q1.*
FROM

(SELECT  *, ROW_NUMBER ()  OVER (PARTITION BY subject_id ORDER BY STRFTIME('%Y-%m-%d %H:%M:%S', admittime) ASC)  RowNum

from 

df_admissions) Q1 

WHERE Q1. RowNum = 1

"""
df_first_admission =sqldf(first_query, globals())

# %%
df_first_admission
# Out:
#     subject_id   hadm_id            admittime            dischtime deathtime  \
# 0     10000032  22595853  2180-05-06T22:23:00  2180-05-07T17:15:00      None
# 1     10001217  24597018  2157-11-18T22:56:00  2157-11-25T18:00:00      None
# 2     10001725  25563031  2110-04-11T15:08:00  2110-04-14T15:00:00      None
# 3     10002428  25797028  2155-07-14T19:15:00  2155-07-15T18:37:00      None
# 4     10002495  24982426  2141-05-22T20:17:00  2141-05-29T17:41:00      None
# ..         ...       ...                  ...                  ...       ...
# 95    10038999  27189241  2131-05-22T21:49:00  2131-06-04T13:43:00      None
# 96    10039708  20572787  2138-10-30T23:30:00  2138-11-06T23:30:00      None
# 97    10039831  26924951  2115-12-28T07:15:00  2116-01-02T14:34:00      None
# 98    10039997  24294180  2134-09-07T12:00:00  2134-09-11T13:10:00      None
# 99    10040025  27125816  2143-03-18T12:34:00  2143-03-19T12:00:00      None
#
#                  admission_type      admission_location  \
# 0                        URGENT  TRANSFER FROM HOSPITAL
# 1                      EW EMER.          EMERGENCY ROOM
# 2                      EW EMER.                    PACU
# 3                EU OBSERVATION          EMERGENCY ROOM
# 4                        URGENT  TRANSFER FROM HOSPITAL
# ..                          ...                     ...
# 95            OBSERVATION ADMIT          EMERGENCY ROOM
# 96                     EW EMER.          EMERGENCY ROOM
# 97  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL
# 98  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL
# 99       AMBULATORY OBSERVATION          PROCEDURE SITE
#
#           discharge_location insurance language marital_status  \
# 0                       HOME     Other  ENGLISH        WIDOWED
# 1           HOME HEALTH CARE     Other        ?        MARRIED
# 2                       HOME     Other  ENGLISH        MARRIED
# 3                       None  Medicare  ENGLISH        WIDOWED
# 4   SKILLED NURSING FACILITY  Medicare  ENGLISH        MARRIED
# ..                       ...       ...      ...            ...
# 95                      HOME  Medicare  ENGLISH         SINGLE
# 96            AGAINST ADVICE     Other  ENGLISH         SINGLE
# 97          HOME HEALTH CARE     Other  ENGLISH        MARRIED
# 98                      HOME  Medicare  ENGLISH        MARRIED
# 99                      None     Other  ENGLISH       DIVORCED
#
#                  ethnicity            edregtime            edouttime  \
# 0                    WHITE  2180-05-06T19:17:00  2180-05-06T23:30:00
# 1                    WHITE  2157-11-18T17:38:00  2157-11-19T01:24:00
# 2                    WHITE                 None                 None
# 3                    WHITE  2155-07-14T16:58:00  2155-07-14T20:04:00
# 4                  UNKNOWN                 None                 None
# ..                     ...                  ...                  ...
# 95                   WHITE  2131-05-22T20:33:00  2131-05-22T21:28:00
# 96  BLACK/AFRICAN AMERICAN  2138-10-30T17:27:00  2138-10-31T00:19:00
# 97        UNABLE TO OBTAIN                 None                 None
# 98  BLACK/AFRICAN AMERICAN                 None                 None
# 99                   WHITE                 None                 None
#
#     hospital_expire_flag  RowNum
# 0                      0       1
# 1                      0       1
# 2                      0       1
# 3                      0       1
# 4                      0       1
# ..                   ...     ...
# 95                     0       1
# 96                     0       1
# 97                     0       1
# 98                     0       1
# 99                     0       1
#
# [100 rows x 16 columns]

# %% [markdown]
# ####  b. Only the Albumin results from the first 24h from hospital admission.

# %% [markdown]
# #### To answer the criteria of question b. The queries were divided to facilitate the understanding of the solution presented.
# #### Each step results in a dataframe.
#
# * 1: Selecting admission with albumin results --> df_albumin_lab
# * 2: Filtering lab events in the first 24h --> df_time_event_lab
# * 3: Removing outliers --> df_clear_admission
# * 4: Counting number of deaths

# %% [markdown]
# #### 1) Select only the admissions where lab_events is Albumin, joining the tables: first_admission, df_labevents and df_labitems

# %%
query_only_albumin_lab ="""

SELECT *
FROM
df_first_admission

JOIN df_labevents ON df_labevents.subject_id = df_first_admission.subject_id and df_labevents.hadm_id = df_first_admission.hadm_id


JOIN df_labitems ON df_labitems.itemid = df_labevents.itemid

where upper(df_labitems.label) like '%ALBUMIN%'


"""
df_albumin_lab =sqldf(query_only_albumin_lab, globals())

# %%
df_albumin_lab
# Out:
#      subject_id   hadm_id            admittime            dischtime  \
# 0      10002495  24982426  2141-05-22T20:17:00  2141-05-29T17:41:00
# 1      10002495  24982426  2141-05-22T20:17:00  2141-05-29T17:41:00
# 2      10003400  26090619  2134-06-06T02:25:00  2134-06-07T15:05:00
# 3      10004235  24181354  2196-02-24T14:38:00  2196-03-04T14:02:00
# 4      10004235  24181354  2196-02-24T14:38:00  2196-03-04T14:02:00
# ..          ...       ...                  ...                  ...
# 123    10007818  22987108  2146-06-10T16:37:00  2146-07-12T00:00:00
# 124    10007818  22987108  2146-06-10T16:37:00  2146-07-12T00:00:00
# 125    10007818  22987108  2146-06-10T16:37:00  2146-07-12T00:00:00
# 126    10038081  20755971  2115-09-27T20:40:00  2115-10-12T00:00:00
# 127    10021487  28998349  2116-12-03T00:23:00  2116-12-28T13:19:00
#
#                deathtime admission_type      admission_location  \
# 0                   None         URGENT  TRANSFER FROM HOSPITAL
# 1                   None         URGENT  TRANSFER FROM HOSPITAL
# 2                   None       EW EMER.          EMERGENCY ROOM
# 3                   None         URGENT  TRANSFER FROM HOSPITAL
# 4                   None         URGENT  TRANSFER FROM HOSPITAL
# ..                   ...            ...                     ...
# 123  2146-07-12T20:50:00   DIRECT EMER.      PHYSICIAN REFERRAL
# 124  2146-07-12T20:50:00   DIRECT EMER.      PHYSICIAN REFERRAL
# 125  2146-07-12T20:50:00   DIRECT EMER.      PHYSICIAN REFERRAL
# 126  2115-10-12T22:20:00         URGENT  TRANSFER FROM HOSPITAL
# 127                 None       EW EMER.          EMERGENCY ROOM
#
#            discharge_location insurance language  ... ref_range_lower  \
# 0    SKILLED NURSING FACILITY  Medicare  ENGLISH  ...             3.5
# 1    SKILLED NURSING FACILITY  Medicare  ENGLISH  ...             3.5
# 2            HOME HEALTH CARE  Medicare  ENGLISH  ...             3.5
# 3    SKILLED NURSING FACILITY  Medicaid  ENGLISH  ...             3.5
# 4    SKILLED NURSING FACILITY  Medicaid  ENGLISH  ...             3.5
# ..                        ...       ...      ...  ...             ...
# 123                      DIED  Medicare  ENGLISH  ...             NaN
# 124                      DIED  Medicare  ENGLISH  ...             NaN
# 125                      DIED  Medicare  ENGLISH  ...             NaN
# 126                      DIED     Other        ?  ...             NaN
# 127                      HOME     Other  ENGLISH  ...             NaN
#
#     ref_range_upper      flag priority          comments  itemid  \
# 0               5.2  abnormal  ROUTINE              None   50862
# 1               5.2  abnormal     STAT              None   50862
# 2               5.2  abnormal  ROUTINE              None   50862
# 3               5.2  abnormal     STAT              None   50862
# 4               5.2  abnormal  ROUTINE              None   50862
# ..              ...       ...      ...               ...     ...
# 123             NaN      None     STAT              None   50835
# 124             NaN      None  ROUTINE              None   50835
# 125             NaN      None     STAT              None   50835
# 126             NaN      None  ROUTINE  LESS THAN 1.0.     50835
# 127             NaN      None  ROUTINE              None   51046
#
#                 label    fluid   category  loinc_code
# 0             Albumin    Blood  Chemistry      1751-7
# 1             Albumin    Blood  Chemistry      1751-7
# 2             Albumin    Blood  Chemistry      1751-7
# 3             Albumin    Blood  Chemistry      1751-7
# 4             Albumin    Blood  Chemistry      1751-7
# ..                ...      ...        ...         ...
# 123  Albumin, Ascites  Ascites  Chemistry        None
# 124  Albumin, Ascites  Ascites  Chemistry        None
# 125  Albumin, Ascites  Ascites  Chemistry        None
# 126  Albumin, Ascites  Ascites  Chemistry        None
# 127  Albumin, Pleural  Pleural  Chemistry        None
#
# [128 rows x 36 columns]

# %% [markdown]
# ####  2) Filtering admissions respecting the criteria of lab events that were held after 24 hours of admission
#
# ##### The attributes used to count the hours were "admittime" from the admission table and "charttime" from the labevents table
#
# * Q1: Internal query to get hours via julianday function ---> generating "time_event_lab" attribute: hours count
# * Q2: External query to return admissions that are within the requested range

# %%
query_time_event_lab="""
SELECT Q1.*
FROM
(SELECT df_albumin_lab.*
   , CAST((julianday(charttime) - julianday(admittime))*24 AS real) AS time_event_lab
   
FROM df_albumin_lab) Q1 

WHERE Q1.time_event_lab <=24;

"""
df_time_event_lab =sqldf(query_time_event_lab, globals())

# %%
df_time_event_lab
# Out:
#     subject_id     hadm_id            admittime            dischtime  \
# 0     10004720  22081550.0  2186-11-12T18:01:00  2186-11-17T18:30:00
# 1     10004720  22081550.0  2186-11-12T18:01:00  2186-11-17T18:30:00
# 2     10005817  20626031.0  2132-12-12T01:43:00  2132-12-20T15:04:00
# 3     10005866  26158160.0  2146-06-06T00:50:00  2146-06-09T16:45:00
# 4     10007818  22987108.0  2146-06-10T16:37:00  2146-07-12T00:00:00
# 5     10007928  20338077.0  2129-04-05T22:56:00  2129-04-11T17:25:00
# 6     10009628  25926192.0  2153-09-17T17:08:00  2153-09-25T13:20:00
# 7     10012552  27089790.0  2140-03-22T17:18:00  2140-03-30T14:10:00
# 8     10016150  29374560.0  2142-05-10T15:05:00  2142-05-15T19:49:00
# 9     10016810  20973395.0  2185-06-16T01:31:00  2185-06-21T15:55:00
# 10    10018423  29366372.0  2167-05-03T21:24:00  2167-05-11T12:57:00
# 11    10019172  21540783.0  2118-10-08T14:00:00  2118-10-11T20:15:00
# 12    10019385  20297618.0  2180-02-15T20:28:00  2180-02-25T13:45:00
# 13    10019777  27738145.0  2187-02-10T18:57:00  2187-02-27T13:22:00
# 14    10019917  22585261.0  2182-01-07T23:25:00  2182-01-10T16:52:00
# 15    10020640  27984218.0  2153-02-13T00:22:00  2153-02-20T13:52:00
# 16    10020740  23831430.0  2150-03-11T15:34:00  2150-04-25T13:50:00
# 17    10020786  23488445.0  2189-06-09T12:45:00  2189-06-13T17:20:00
# 18    10020944  29974575.0  2131-02-27T15:34:00  2131-03-13T17:01:00
# 19    10021118  24490144.0  2161-11-15T20:10:00  2161-11-23T16:00:00
# 20    10021312  25020332.0  2113-08-16T00:32:00  2113-08-18T17:35:00
# 21    10021487  28998349.0  2116-12-03T00:23:00  2116-12-28T13:19:00
# 22    10021938  23112364.0  2181-10-13T01:48:00  2181-10-14T17:40:00
# 23    10029291  22205327.0  2123-02-20T01:59:00  2123-03-10T15:30:00
# 24    10029484  20764029.0  2160-11-08T04:16:00  2160-11-11T11:40:00
# 25    10032725  25177949.0  2143-02-17T14:20:00  2143-03-16T17:15:00
# 26    10035185  22580999.0  2120-05-12T12:53:00  2120-05-17T16:00:00
# 27    10037861  24256866.0  2115-10-09T20:28:00  2115-10-18T16:50:00
# 28    10037975  27617929.0  2185-01-17T19:11:00  2185-01-22T14:25:00
# 29    10037975  27617929.0  2185-01-17T19:11:00  2185-01-22T14:25:00
# 30    10038081  20755971.0  2115-09-27T20:40:00  2115-10-12T00:00:00
# 31    10038081  20755971.0  2115-09-27T20:40:00  2115-10-12T00:00:00
# 32    10038992  22797747.0  2185-11-02T18:26:00  2185-11-08T16:22:00
# 33    10038999  27189241.0  2131-05-22T21:49:00  2131-06-04T13:43:00
# 34    10000032  22595853.0  2180-05-06T22:23:00  2180-05-07T17:15:00
# 35    10006053  22942076.0  2111-11-13T23:39:00  2111-11-15T17:20:00
# 36    10007818  22987108.0  2146-06-10T16:37:00  2146-07-12T00:00:00
#
#               deathtime     admission_type         admission_location  \
# 0   2186-11-17T18:30:00           EW EMER.  INFORMATION NOT AVAILABLE
# 1   2186-11-17T18:30:00           EW EMER.  INFORMATION NOT AVAILABLE
# 2                  None             URGENT     TRANSFER FROM HOSPITAL
# 3                  None           EW EMER.             EMERGENCY ROOM
# 4   2146-07-12T20:50:00       DIRECT EMER.         PHYSICIAN REFERRAL
# 5                  None           EW EMER.             EMERGENCY ROOM
# 6                  None             URGENT     TRANSFER FROM HOSPITAL
# 7                  None             URGENT     TRANSFER FROM HOSPITAL
# 8                  None           EW EMER.             PROCEDURE SITE
# 9                  None           EW EMER.             EMERGENCY ROOM
# 10                 None           EW EMER.             EMERGENCY ROOM
# 11                 None           ELECTIVE         PHYSICIAN REFERRAL
# 12                 None             URGENT     TRANSFER FROM HOSPITAL
# 13                 None           EW EMER.             EMERGENCY ROOM
# 14                 None             URGENT     TRANSFER FROM HOSPITAL
# 15                 None           EW EMER.             EMERGENCY ROOM
# 16                 None             URGENT     TRANSFER FROM HOSPITAL
# 17                 None             URGENT     TRANSFER FROM HOSPITAL
# 18                 None           EW EMER.             EMERGENCY ROOM
# 19                 None             URGENT     TRANSFER FROM HOSPITAL
# 20                 None             URGENT     TRANSFER FROM HOSPITAL
# 21                 None           EW EMER.             EMERGENCY ROOM
# 22                 None           EW EMER.             EMERGENCY ROOM
# 23                 None           EW EMER.             EMERGENCY ROOM
# 24                 None           EW EMER.             EMERGENCY ROOM
# 25                 None           EW EMER.             EMERGENCY ROOM
# 26                 None             URGENT     TRANSFER FROM HOSPITAL
# 27                 None             URGENT     TRANSFER FROM HOSPITAL
# 28  2185-01-22T14:25:00             URGENT     TRANSFER FROM HOSPITAL
# 29  2185-01-22T14:25:00             URGENT     TRANSFER FROM HOSPITAL
# 30  2115-10-12T22:20:00             URGENT     TRANSFER FROM HOSPITAL
# 31  2115-10-12T22:20:00             URGENT     TRANSFER FROM HOSPITAL
# 32                 None             URGENT     TRANSFER FROM HOSPITAL
# 33                 None  OBSERVATION ADMIT             EMERGENCY ROOM
# 34                 None             URGENT     TRANSFER FROM HOSPITAL
# 35  2111-11-15T17:20:00             URGENT     TRANSFER FROM HOSPITAL
# 36  2146-07-12T20:50:00       DIRECT EMER.         PHYSICIAN REFERRAL
#
#               discharge_location insurance language  ... ref_range_lower  \
# 0                           DIED  Medicare  ENGLISH  ...             3.5
# 1                           DIED  Medicare  ENGLISH  ...             3.5
# 2               HOME HEALTH CARE  Medicare  ENGLISH  ...             3.5
# 3                           HOME  Medicaid  ENGLISH  ...             3.5
# 4                           DIED  Medicare  ENGLISH  ...             3.5
# 5                           HOME     Other  ENGLISH  ...             3.5
# 6               HOME HEALTH CARE  Medicaid        ?  ...             3.5
# 7               HOME HEALTH CARE  Medicare  ENGLISH  ...             3.5
# 8                          REHAB  Medicare  ENGLISH  ...             3.5
# 9                           HOME     Other  ENGLISH  ...             3.5
# 10              HOME HEALTH CARE     Other  ENGLISH  ...             3.5
# 11                          HOME     Other  ENGLISH  ...             3.5
# 12              HOME HEALTH CARE     Other  ENGLISH  ...             3.5
# 13                       HOSPICE     Other  ENGLISH  ...             3.5
# 14                          HOME     Other  ENGLISH  ...             3.5
# 15      SKILLED NURSING FACILITY     Other  ENGLISH  ...             3.5
# 16      SKILLED NURSING FACILITY     Other  ENGLISH  ...             3.5
# 17                          HOME  Medicare  ENGLISH  ...             3.5
# 18      SKILLED NURSING FACILITY  Medicare  ENGLISH  ...             3.5
# 19              HOME HEALTH CARE     Other  ENGLISH  ...             3.5
# 20                          HOME     Other  ENGLISH  ...             3.5
# 21                          HOME     Other  ENGLISH  ...             3.5
# 22                          HOME  Medicare  ENGLISH  ...             3.5
# 23              HOME HEALTH CARE  Medicare  ENGLISH  ...             3.5
# 24                          HOME     Other  ENGLISH  ...             3.5
# 25  CHRONIC/LONG TERM ACUTE CARE     Other  ENGLISH  ...             3.5
# 26              HOME HEALTH CARE     Other  ENGLISH  ...             3.5
# 27              HOME HEALTH CARE  Medicare  ENGLISH  ...             3.5
# 28                          DIED  Medicare  ENGLISH  ...             3.5
# 29                          DIED  Medicare  ENGLISH  ...             3.5
# 30                          DIED     Other        ?  ...             3.5
# 31                          DIED     Other        ?  ...             3.5
# 32              HOME HEALTH CARE  Medicare  ENGLISH  ...             3.5
# 33                          HOME  Medicare  ENGLISH  ...             3.5
# 34                          HOME     Other  ENGLISH  ...             NaN
# 35                          DIED  Medicaid  ENGLISH  ...             NaN
# 36                          DIED  Medicare  ENGLISH  ...             NaN
#
#    ref_range_upper      flag priority          comments             label  \
# 0              5.2  abnormal     STAT              None           Albumin
# 1              5.2  abnormal     STAT              None           Albumin
# 2              5.2  abnormal     STAT              None           Albumin
# 3              5.2  abnormal     STAT              None           Albumin
# 4              5.2      None     STAT              None           Albumin
# 5              5.2  abnormal     STAT              None           Albumin
# 6              5.2      None     STAT              None           Albumin
# 7              5.2      None     STAT              None           Albumin
# 8              5.2      None  ROUTINE              None           Albumin
# 9              5.2  abnormal  ROUTINE              None           Albumin
# 10             5.2      None  ROUTINE              None           Albumin
# 11             5.2      None     STAT              None           Albumin
# 12             5.2      None     STAT              None           Albumin
# 13             5.2  abnormal  ROUTINE              None           Albumin
# 14             5.2  abnormal     STAT              None           Albumin
# 15             5.2  abnormal  ROUTINE              None           Albumin
# 16             5.2  abnormal     STAT              None           Albumin
# 17             5.2  abnormal  ROUTINE              None           Albumin
# 18             5.2  abnormal  ROUTINE              None           Albumin
# 19             5.2      None     STAT              None           Albumin
# 20             5.2  abnormal     STAT              None           Albumin
# 21             5.2  abnormal  ROUTINE              None           Albumin
# 22             5.2      None     STAT              None           Albumin
# 23             5.2  abnormal  ROUTINE              None           Albumin
# 24             5.2      None     STAT              None           Albumin
# 25             5.2      None  ROUTINE              None           Albumin
# 26             5.2      None     STAT              None           Albumin
# 27             5.2  abnormal     STAT              None           Albumin
# 28             5.2  abnormal     STAT              None           Albumin
# 29             5.2  abnormal  ROUTINE              None           Albumin
# 30             5.2      None     STAT              None           Albumin
# 31             5.2  abnormal     STAT              None           Albumin
# 32             5.2  abnormal  ROUTINE              None           Albumin
# 33             5.2  abnormal     STAT              None           Albumin
# 34             NaN      None     STAT  LESS THAN 1.0.    Albumin, Ascites
# 35             NaN      None     STAT  LESS THAN 1.0.    Albumin, Ascites
# 36             NaN      None     STAT              None  Albumin, Ascites
#
#       fluid   category  loinc_code time_event_lab
# 0     Blood  Chemistry      1751-7      13.516667
# 1     Blood  Chemistry      1751-7      20.466667
# 2     Blood  Chemistry      1751-7       1.416667
# 3     Blood  Chemistry      1751-7      -2.166667
# 4     Blood  Chemistry      1751-7       2.983333
# 5     Blood  Chemistry      1751-7      18.316667
# 6     Blood  Chemistry      1751-7       2.366667
# 7     Blood  Chemistry      1751-7       3.116667
# 8     Blood  Chemistry      1751-7      16.166667
# 9     Blood  Chemistry      1751-7      23.600000
# 10    Blood  Chemistry      1751-7      19.933333
# 11    Blood  Chemistry      1751-7       5.250000
# 12    Blood  Chemistry      1751-7      11.116667
# 13    Blood  Chemistry      1751-7       8.966667
# 14    Blood  Chemistry      1751-7       4.533333
# 15    Blood  Chemistry      1751-7       5.650000
# 16    Blood  Chemistry      1751-7      11.483333
# 17    Blood  Chemistry      1751-7       1.616667
# 18    Blood  Chemistry      1751-7       2.433333
# 19    Blood  Chemistry      1751-7       1.666667
# 20    Blood  Chemistry      1751-7       4.433333
# 21    Blood  Chemistry      1751-7      11.833333
# 22    Blood  Chemistry      1751-7       2.266667
# 23    Blood  Chemistry      1751-7      16.600000
# 24    Blood  Chemistry      1751-7      12.366667
# 25    Blood  Chemistry      1751-7      17.083333
# 26    Blood  Chemistry      1751-7       2.116667
# 27    Blood  Chemistry      1751-7       0.366667
# 28    Blood  Chemistry      1751-7       0.366667
# 29    Blood  Chemistry      1751-7       7.716667
# 30    Blood  Chemistry      1751-7       1.683333
# 31    Blood  Chemistry      1751-7      12.833333
# 32    Blood  Chemistry      1751-7      12.550000
# 33    Blood  Chemistry      1751-7       7.083333
# 34  Ascites  Chemistry        None      11.800000
# 35  Ascites  Chemistry        None       7.183333
# 36  Ascites  Chemistry        None      22.533333
#
# [37 rows x 34 columns]

# %% [markdown]
# ####  3) Checking inconsistency
#
# ##### After filtering the hours of the lab events, it was verified that it contained data in which the lab_event was performed before the date of admission of hospitalization. It can be classified as an inconsistency in the data, or an alert to report to professionals.
#
# ##### However, for the resolution sequence, the admission: 26158160.0 of the patient: 10005866 was discarded from the count

# %%
df_clear_admission = df_time_event_lab.copy()

# %%
df_clear_admission.drop(df_clear_admission.loc[df_clear_admission['time_event_lab']<0].index, inplace=True)

# %% [markdown]
# ### Final table of queries requested, but still needs to perform operations to obtain final conclusions on single-patient mortality

# %%
df_clear_admission.reset_index()
# Out:
#     index  subject_id     hadm_id            admittime            dischtime  \
# 0       0    10004720  22081550.0  2186-11-12T18:01:00  2186-11-17T18:30:00
# 1       1    10004720  22081550.0  2186-11-12T18:01:00  2186-11-17T18:30:00
# 2       2    10005817  20626031.0  2132-12-12T01:43:00  2132-12-20T15:04:00
# 3       4    10007818  22987108.0  2146-06-10T16:37:00  2146-07-12T00:00:00
# 4       5    10007928  20338077.0  2129-04-05T22:56:00  2129-04-11T17:25:00
# 5       6    10009628  25926192.0  2153-09-17T17:08:00  2153-09-25T13:20:00
# 6       7    10012552  27089790.0  2140-03-22T17:18:00  2140-03-30T14:10:00
# 7       8    10016150  29374560.0  2142-05-10T15:05:00  2142-05-15T19:49:00
# 8       9    10016810  20973395.0  2185-06-16T01:31:00  2185-06-21T15:55:00
# 9      10    10018423  29366372.0  2167-05-03T21:24:00  2167-05-11T12:57:00
# 10     11    10019172  21540783.0  2118-10-08T14:00:00  2118-10-11T20:15:00
# 11     12    10019385  20297618.0  2180-02-15T20:28:00  2180-02-25T13:45:00
# 12     13    10019777  27738145.0  2187-02-10T18:57:00  2187-02-27T13:22:00
# 13     14    10019917  22585261.0  2182-01-07T23:25:00  2182-01-10T16:52:00
# 14     15    10020640  27984218.0  2153-02-13T00:22:00  2153-02-20T13:52:00
# 15     16    10020740  23831430.0  2150-03-11T15:34:00  2150-04-25T13:50:00
# 16     17    10020786  23488445.0  2189-06-09T12:45:00  2189-06-13T17:20:00
# 17     18    10020944  29974575.0  2131-02-27T15:34:00  2131-03-13T17:01:00
# 18     19    10021118  24490144.0  2161-11-15T20:10:00  2161-11-23T16:00:00
# 19     20    10021312  25020332.0  2113-08-16T00:32:00  2113-08-18T17:35:00
# 20     21    10021487  28998349.0  2116-12-03T00:23:00  2116-12-28T13:19:00
# 21     22    10021938  23112364.0  2181-10-13T01:48:00  2181-10-14T17:40:00
# 22     23    10029291  22205327.0  2123-02-20T01:59:00  2123-03-10T15:30:00
# 23     24    10029484  20764029.0  2160-11-08T04:16:00  2160-11-11T11:40:00
# 24     25    10032725  25177949.0  2143-02-17T14:20:00  2143-03-16T17:15:00
# 25     26    10035185  22580999.0  2120-05-12T12:53:00  2120-05-17T16:00:00
# 26     27    10037861  24256866.0  2115-10-09T20:28:00  2115-10-18T16:50:00
# 27     28    10037975  27617929.0  2185-01-17T19:11:00  2185-01-22T14:25:00
# 28     29    10037975  27617929.0  2185-01-17T19:11:00  2185-01-22T14:25:00
# 29     30    10038081  20755971.0  2115-09-27T20:40:00  2115-10-12T00:00:00
# 30     31    10038081  20755971.0  2115-09-27T20:40:00  2115-10-12T00:00:00
# 31     32    10038992  22797747.0  2185-11-02T18:26:00  2185-11-08T16:22:00
# 32     33    10038999  27189241.0  2131-05-22T21:49:00  2131-06-04T13:43:00
# 33     34    10000032  22595853.0  2180-05-06T22:23:00  2180-05-07T17:15:00
# 34     35    10006053  22942076.0  2111-11-13T23:39:00  2111-11-15T17:20:00
# 35     36    10007818  22987108.0  2146-06-10T16:37:00  2146-07-12T00:00:00
#
#               deathtime     admission_type         admission_location  \
# 0   2186-11-17T18:30:00           EW EMER.  INFORMATION NOT AVAILABLE
# 1   2186-11-17T18:30:00           EW EMER.  INFORMATION NOT AVAILABLE
# 2                  None             URGENT     TRANSFER FROM HOSPITAL
# 3   2146-07-12T20:50:00       DIRECT EMER.         PHYSICIAN REFERRAL
# 4                  None           EW EMER.             EMERGENCY ROOM
# 5                  None             URGENT     TRANSFER FROM HOSPITAL
# 6                  None             URGENT     TRANSFER FROM HOSPITAL
# 7                  None           EW EMER.             PROCEDURE SITE
# 8                  None           EW EMER.             EMERGENCY ROOM
# 9                  None           EW EMER.             EMERGENCY ROOM
# 10                 None           ELECTIVE         PHYSICIAN REFERRAL
# 11                 None             URGENT     TRANSFER FROM HOSPITAL
# 12                 None           EW EMER.             EMERGENCY ROOM
# 13                 None             URGENT     TRANSFER FROM HOSPITAL
# 14                 None           EW EMER.             EMERGENCY ROOM
# 15                 None             URGENT     TRANSFER FROM HOSPITAL
# 16                 None             URGENT     TRANSFER FROM HOSPITAL
# 17                 None           EW EMER.             EMERGENCY ROOM
# 18                 None             URGENT     TRANSFER FROM HOSPITAL
# 19                 None             URGENT     TRANSFER FROM HOSPITAL
# 20                 None           EW EMER.             EMERGENCY ROOM
# 21                 None           EW EMER.             EMERGENCY ROOM
# 22                 None           EW EMER.             EMERGENCY ROOM
# 23                 None           EW EMER.             EMERGENCY ROOM
# 24                 None           EW EMER.             EMERGENCY ROOM
# 25                 None             URGENT     TRANSFER FROM HOSPITAL
# 26                 None             URGENT     TRANSFER FROM HOSPITAL
# 27  2185-01-22T14:25:00             URGENT     TRANSFER FROM HOSPITAL
# 28  2185-01-22T14:25:00             URGENT     TRANSFER FROM HOSPITAL
# 29  2115-10-12T22:20:00             URGENT     TRANSFER FROM HOSPITAL
# 30  2115-10-12T22:20:00             URGENT     TRANSFER FROM HOSPITAL
# 31                 None             URGENT     TRANSFER FROM HOSPITAL
# 32                 None  OBSERVATION ADMIT             EMERGENCY ROOM
# 33                 None             URGENT     TRANSFER FROM HOSPITAL
# 34  2111-11-15T17:20:00             URGENT     TRANSFER FROM HOSPITAL
# 35  2146-07-12T20:50:00       DIRECT EMER.         PHYSICIAN REFERRAL
#
#               discharge_location insurance  ... ref_range_lower  \
# 0                           DIED  Medicare  ...             3.5
# 1                           DIED  Medicare  ...             3.5
# 2               HOME HEALTH CARE  Medicare  ...             3.5
# 3                           DIED  Medicare  ...             3.5
# 4                           HOME     Other  ...             3.5
# 5               HOME HEALTH CARE  Medicaid  ...             3.5
# 6               HOME HEALTH CARE  Medicare  ...             3.5
# 7                          REHAB  Medicare  ...             3.5
# 8                           HOME     Other  ...             3.5
# 9               HOME HEALTH CARE     Other  ...             3.5
# 10                          HOME     Other  ...             3.5
# 11              HOME HEALTH CARE     Other  ...             3.5
# 12                       HOSPICE     Other  ...             3.5
# 13                          HOME     Other  ...             3.5
# 14      SKILLED NURSING FACILITY     Other  ...             3.5
# 15      SKILLED NURSING FACILITY     Other  ...             3.5
# 16                          HOME  Medicare  ...             3.5
# 17      SKILLED NURSING FACILITY  Medicare  ...             3.5
# 18              HOME HEALTH CARE     Other  ...             3.5
# 19                          HOME     Other  ...             3.5
# 20                          HOME     Other  ...             3.5
# 21                          HOME  Medicare  ...             3.5
# 22              HOME HEALTH CARE  Medicare  ...             3.5
# 23                          HOME     Other  ...             3.5
# 24  CHRONIC/LONG TERM ACUTE CARE     Other  ...             3.5
# 25              HOME HEALTH CARE     Other  ...             3.5
# 26              HOME HEALTH CARE  Medicare  ...             3.5
# 27                          DIED  Medicare  ...             3.5
# 28                          DIED  Medicare  ...             3.5
# 29                          DIED     Other  ...             3.5
# 30                          DIED     Other  ...             3.5
# 31              HOME HEALTH CARE  Medicare  ...             3.5
# 32                          HOME  Medicare  ...             3.5
# 33                          HOME     Other  ...             NaN
# 34                          DIED  Medicaid  ...             NaN
# 35                          DIED  Medicare  ...             NaN
#
#    ref_range_upper      flag priority          comments             label  \
# 0              5.2  abnormal     STAT              None           Albumin
# 1              5.2  abnormal     STAT              None           Albumin
# 2              5.2  abnormal     STAT              None           Albumin
# 3              5.2      None     STAT              None           Albumin
# 4              5.2  abnormal     STAT              None           Albumin
# 5              5.2      None     STAT              None           Albumin
# 6              5.2      None     STAT              None           Albumin
# 7              5.2      None  ROUTINE              None           Albumin
# 8              5.2  abnormal  ROUTINE              None           Albumin
# 9              5.2      None  ROUTINE              None           Albumin
# 10             5.2      None     STAT              None           Albumin
# 11             5.2      None     STAT              None           Albumin
# 12             5.2  abnormal  ROUTINE              None           Albumin
# 13             5.2  abnormal     STAT              None           Albumin
# 14             5.2  abnormal  ROUTINE              None           Albumin
# 15             5.2  abnormal     STAT              None           Albumin
# 16             5.2  abnormal  ROUTINE              None           Albumin
# 17             5.2  abnormal  ROUTINE              None           Albumin
# 18             5.2      None     STAT              None           Albumin
# 19             5.2  abnormal     STAT              None           Albumin
# 20             5.2  abnormal  ROUTINE              None           Albumin
# 21             5.2      None     STAT              None           Albumin
# 22             5.2  abnormal  ROUTINE              None           Albumin
# 23             5.2      None     STAT              None           Albumin
# 24             5.2      None  ROUTINE              None           Albumin
# 25             5.2      None     STAT              None           Albumin
# 26             5.2  abnormal     STAT              None           Albumin
# 27             5.2  abnormal     STAT              None           Albumin
# 28             5.2  abnormal  ROUTINE              None           Albumin
# 29             5.2      None     STAT              None           Albumin
# 30             5.2  abnormal     STAT              None           Albumin
# 31             5.2  abnormal  ROUTINE              None           Albumin
# 32             5.2  abnormal     STAT              None           Albumin
# 33             NaN      None     STAT  LESS THAN 1.0.    Albumin, Ascites
# 34             NaN      None     STAT  LESS THAN 1.0.    Albumin, Ascites
# 35             NaN      None     STAT              None  Albumin, Ascites
#
#       fluid   category  loinc_code  time_event_lab
# 0     Blood  Chemistry      1751-7       13.516667
# 1     Blood  Chemistry      1751-7       20.466667
# 2     Blood  Chemistry      1751-7        1.416667
# 3     Blood  Chemistry      1751-7        2.983333
# 4     Blood  Chemistry      1751-7       18.316667
# 5     Blood  Chemistry      1751-7        2.366667
# 6     Blood  Chemistry      1751-7        3.116667
# 7     Blood  Chemistry      1751-7       16.166667
# 8     Blood  Chemistry      1751-7       23.600000
# 9     Blood  Chemistry      1751-7       19.933333
# 10    Blood  Chemistry      1751-7        5.250000
# 11    Blood  Chemistry      1751-7       11.116667
# 12    Blood  Chemistry      1751-7        8.966667
# 13    Blood  Chemistry      1751-7        4.533333
# 14    Blood  Chemistry      1751-7        5.650000
# 15    Blood  Chemistry      1751-7       11.483333
# 16    Blood  Chemistry      1751-7        1.616667
# 17    Blood  Chemistry      1751-7        2.433333
# 18    Blood  Chemistry      1751-7        1.666667
# 19    Blood  Chemistry      1751-7        4.433333
# 20    Blood  Chemistry      1751-7       11.833333
# 21    Blood  Chemistry      1751-7        2.266667
# 22    Blood  Chemistry      1751-7       16.600000
# 23    Blood  Chemistry      1751-7       12.366667
# 24    Blood  Chemistry      1751-7       17.083333
# 25    Blood  Chemistry      1751-7        2.116667
# 26    Blood  Chemistry      1751-7        0.366667
# 27    Blood  Chemistry      1751-7        0.366667
# 28    Blood  Chemistry      1751-7        7.716667
# 29    Blood  Chemistry      1751-7        1.683333
# 30    Blood  Chemistry      1751-7       12.833333
# 31    Blood  Chemistry      1751-7       12.550000
# 32    Blood  Chemistry      1751-7        7.083333
# 33  Ascites  Chemistry        None       11.800000
# 34  Ascites  Chemistry        None        7.183333
# 35  Ascites  Chemistry        None       22.533333
#
# [36 rows x 35 columns]

# %% [markdown]
# ####  4) Counting number of deaths
#
# ##### This indicates whether the patient died within the given hospitalization.
# #####  1: indicates death in the hospital
# #####  0: indicates survival to hospital discharge.

# %% [markdown]
# ### Total unique patients who had admissions: 32 - Considering the final results - provides from requirements (a and b)

# %%
print(f" The number of records is {len(df_clear_admission)}, but the number of patients is {len(df_clear_admission['subject_id'].unique())}")
# Out:
#  The number of records is 36, but the number of patients is 32

# %% [markdown]
# #### Number of unique patients who did not die - FINAL Result

# %%
#df_clear_admission.notna()
admission_no_death_final =df_clear_admission[df_clear_admission['deathtime'].isnull()]
print(f"Unique number of patients who did not die: {len(admission_no_death_final['subject_id'].unique())}")
# Out:
# Unique number of patients who did not die: 27

# %% [markdown]
# #### Number of unique patients who died - FINAL Result

# %%
admission_death_final =df_clear_admission[df_clear_admission['deathtime'].notnull()]
print(f"Unique number of patients who died: {len(admission_death_final['subject_id'].unique())}")
# Out:
# Unique number of patients who died: 5

# %% [markdown]
# # Formalizing the performance of albumin in predicting in-hospital mortality

# %% [markdown]
# ### Total unique patients who had admissions: 100 - Considering the admission table with the first admission of each patient

# %%
print(f"Total unique patients who had admissions: {len(df_first_admission['subject_id'].unique())}")
# Out:
# Total unique patients who had admissions: 100

# %% [markdown]
# #### Number of unique patients who did not die - FIRST Admission

# %%
#df_clear_admission.notna()
admission_no_death_no_filter =df_first_admission[df_first_admission['deathtime'].isnull()]
print(f"Unique number of patients who did not die: {len(admission_no_death_no_filter['subject_id'].unique())}")
# Out:
# Unique number of patients who did not die: 95

# %% [markdown]
# #### Number of unique patients who died - FIRST Admission

# %%
admission_death_no_filter =df_first_admission[df_first_admission['deathtime'].notnull()]
print(f"Unique number of patients who died: {len(admission_death_no_filter['subject_id'].unique())}")
# Out:
# Unique number of patients who died: 5

# %% [markdown]
# ### Summarizing
#
# * Total unique patients who had admissions: 100
#     * NO-FILTER albumin --- Unique number of patients who did not die: 95
#     * NO-FILTER albumin --- Unique number of patients who  died: 5
#
#
#
# * Total unique patients who had admissions apply all condiction(a and b): 32
#     * Unique number of patients who did not die: 27
#     * Unique number of patients who  died: 5

# %% [markdown]
# ### Survival and mortality rate not considering only albumin tests

# %%
survival_rate =    ( len(admission_no_death_no_filter) / len(df_first_admission)) *100
print(f"The survival rate not considering albumin tests is: {survival_rate} %")
# Out:
# The survival rate not considering albumin tests is: 95.0 %

# %%
mortality_rate = (len(admission_death_no_filter) /  len(df_first_admission)) *100
print(f"The mortality rate not considering albumin tests is: {mortality_rate} %")
# Out:
# The mortality rate not considering albumin tests is: 5.0 %

# %% [markdown]
# ### Survival and mortality rate considering albumin tests

# %%
survival_rate_final = ( len(admission_no_death_final) / len(df_clear_admission)) *100
print(f"{survival_rate_final} %")
# Out:
# 75.0 %

# %%
mortality_rate_final = (len(admission_death_final) /  len(df_clear_admission)) *100
print(f"{mortality_rate_final} %")
# Out:
# 25.0 %

# %% [markdown]
# ### Final Insights
#
# After analyzing the data of admissions, exams, stays.
# The final table --> "df_clear_admission" with the exam results (lab_events) of admissions contains 36 records with 32 unique patients.
#
# We can notice that without performing the requested filters in relation to the exclusivity of the presence of the albumin test. The probability of survival is 95%, and 5% for mortality. When we apply the filter of the existence of albumin tests, the percentage of survival drops to 75%, and mortality increases to 25%. It is possible to observe that the presence of the albumin test has a substantial impact on mortality, increasing the probability of death by 20%. By analyzing the data, it was also possible to notice that all patients who had deaths for both filters (not only the albumin test and only the albumin test) had performed tests related to the albumin test.

# %% [markdown]
# * By analyzing the data, it was also possible to notice that all patients who had deaths for both filters

# %%
print(f"Unique number of patients who died not considering only albumin tests: {admission_death_no_filter['subject_id'].unique()}")
# Out:
# Unique number of patients who died not considering only albumin tests: [10004720 10006053 10007818 10037975 10038081]

# %%
print(f"Unique number of patients who died considering  albumin tests: {admission_death_final['subject_id'].unique()}")
# Out:
# Unique number of patients who died considering  albumin tests: [10004720 10007818 10037975 10038081 10006053]
